# %%
# Install and setup
# !git clone https://github.com/mahsaabadian/DSA-RL-Tracker.git
# %cd DSA-RL-Tracker
# !pip install -r Experiment1/requirements.txt
# Out:
# fatal: destination path 'DSA-RL-Tracker' already exists and is not an empty directory.
# /content/DSA-RL-Tracker
# ...

# %%
# Check CUDA / GPU availability
import torch, subprocess
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device count:", torch.cuda.device_count())
    print("CUDA device name:", torch.cuda.get_device_name(0))
    try:
        print("nvcc version:")
        subprocess.run(["nvcc", "--version"], check=False)
    except FileNotFoundError:
        print("nvcc not found in PATH")
else:
    print("GPU not available — training will fall back to CPU")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# CUDA device count: 1
# CUDA device name: NVIDIA A100-SXM4-40GB
# nvcc version:

# %%
# Run Experiment5_reward_config training (full curriculum with reward config)
# %cd /content/DSA-RL-Tracker/Experiment5_reward_config
# !python src/train.py --experiment_name colab_exp5_reward --curve_config config/curve_config.json --reward_config config/reward_config.json --base_seed 42

#
# Out:
# /content/DSA-RL-Tracker/Experiment5_reward_config
# ✅ GPU detected: NVIDIA A100-SXM4-40GB
#    CUDA Version: 12.6
# ✓ Loaded curve configuration from: /content/DSA-RL-Tracker/Experiment5_reward_config/config/curve_config.json
# ✓ Loaded reward configuration from: /content/DSA-RL-Tracker/Experiment5_reward_config/config/reward_config.json
# ✓ Copied curve configuration to: /content/DSA-RL-Tracker/Experiment5_reward_config/runs/colab_exp5_quick_20260105_040118/curve_config.json
# ✓ Copied reward configuration to: /content/DSA-RL-Tracker/Experiment5_reward_config/runs/colab_exp5_quick_20260105_040118/reward_config.json
# ✓ Loaded 3 training stages from config
# === STARTING UNIFIED RL TRAINING ===
# Number of Stages: 3
# Device: cuda | Actions: 9 (Inc. STOP)
# Base Seed: 42 (for reproducibility)
# Curve Generation: On-The-Fly
# Run Directory: /content/DSA-RL-Tracker/Experiment5_reward_config/runs/colab_exp5_quick_20260105_040118
# ...

# %%
#Push results (includes weights) to Git
# !git config --global user.email "mahsa.abadian@gmail.com"
# !git config --global user.name "MahsaAbadian"
# !git add runs/
# !git commit -m "Add training results from Colab"

try:
    from google.colab import userdata
    token = userdata.get('GITHUB_TOKEN')
    if token:
        # Use token to authenticate push
        # !git remote set-url origin https://{token}@github.com/MahsaAbadian/DSA-RL-Tracker.git
        # !git push origin main
    else:
        print("⚠️ GITHUB_TOKEN not found in Colab Secrets. Skipping push.")
except Exception as e:
    print(f"❌ Error pushing to GitHub: {e}")
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
