# %%
# Install and setup
# !git clone https://github.com/mahsaabadian/DSA-RL-Tracker.git
# %cd DSA-RL-Tracker
# !pip install -r Experiment1/requirements.txt

# %%
# Run Experiment2_separate_stop_shared_backbone training (shared backbone + stop head)
# %cd /content/DSA-RL-Tracker/Experiment2_separate_stop_shared_backbone
# !python src/train.py --experiment_name colab_exp2 --curve_config config/curve_config.json --base_seed 42

# Push results to Git
# !git config --global user.email "colab-trainer@example.com"
# !git config --global user.name "Colab Trainer"
# !git add runs/
# !git commit -m "Add training results from Colab"
# !git push origin main

# %%
# Run Experiment2_separate_stop_shared_backbone inference (replace paths before running)
# %cd /content/DSA-RL-Tracker/Experiment2_separate_stop_shared_backbone
IMAGE_PATH="/content/sample_data/your_image.png"   # TODO: set to your image
WEIGHTS="/content/DSA-RL-Tracker/Experiment2_separate_stop_shared_backbone/runs/YOUR_RUN/checkpoints/actor_Stage3_Realism_ep12000.pth"  # TODO: set to your weights
# !python src/rollout.py --image_path $IMAGE_PATH --actor_weights $WEIGHTS --max_steps 800
