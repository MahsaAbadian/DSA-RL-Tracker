# %%
# Install and setup
# !git clone https://github.com/mahsaabadian/DSA-RL-Tracker.git
# %cd DSA-RL-Tracker
# !pip install -r Experiment1/requirements.txt

# %%
# Run Experiment4_separate_stop_v2 training AND auto-push results
import os
from datetime import datetime

# 1. Run Training
# %cd /content/DSA-RL-Tracker/Experiment4_separate_stop_v2
# !python src/train.py --experiment_name colab_exp2 --curve_config config/curve_config.json --base_seed 42

# 2. Auto-push results to GitHub
print("\n--- TRAINING COMPLETE. Pushing results to GitHub... ---")
# %cd /content/DSA-RL-Tracker/

# Configure git (replace with your details if not already done)
# !git config --global user.email "your-email@example.com"
# !git config --global user.name "Your Name"

# !git add Experiment4_separate_stop_v2/runs/
# !git commit -m "Results: Automated push after Experiment 4 training session"
# !git push origin main

# %%
# Run Experiment4_separate_stop_v2 inference (replace paths before running)
# %cd /content/DSA-RL-Tracker/Experiment4_separate_stop_v2
IMAGE_PATH="/content/sample_data/your_image.png"   # TODO: set to your image
WEIGHTS="/content/DSA-RL-Tracker/Experiment4_separate_stop_v2/runs/YOUR_RUN/checkpoints/actor_Stage3_Realism_ep12000.pth"  # TODO: set to your weights
# !python src/rollout.py --image_path $IMAGE_PATH --actor_weights $WEIGHTS --max_steps 800
